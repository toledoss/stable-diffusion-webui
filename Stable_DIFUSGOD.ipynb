# %% [markdown]
# <a href="https://colab.research.google.com/github/toledoss/stable-diffusion-webui/blob/master/Stable_DIFUSGOD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CONECTAR CON GOOGLE DRIVE

# %% [markdown]
# # **TODO**

# %%
#@title Descargas
#@markdown Aquí se descargan algunos models y vae porque sin ellos no se pueden iniciar el modelo, igual dentro del modelo hay una extension llamada Civitai que te permite descargar modelos directamente desde la WebUI, instala almenos un model desde aquí para poder utilizar Stable Diffusion.
Carpeta_Modelos = "/content/stable-diffusion-webui/models/Stable-diffusion" #@param {type:"string"} 
#@markdown - Escribe la ruta de descarga de los modelos, si no quieres guardarlos en otra carpeta entonces no cambies nada.
import os
CD = "/content/" #@param {type:"string"}

Download_WebUI = True #@param {type:"boolean"}

if Download_WebUI:
  # %cd {CD}
  # !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui #GUI

Filemodel= True #@param {type:"boolean"}
#@markdown - Activalo para crear una carpeta llamada "models" para descargar los modelos ahi dentro.
if Filemodel:
  # %cd /content/  
  os.mkdir('models');
dataset="AnythingV4" #@param ["None", "AnythingV4", "kenshi", "Naifu", "Waifuv1-4", "anime", "hitokomoru-v2", "Izumi", "Healys Anime Blend", "animefull-latest", "Protogen v2.2 Anime", "grapefruit", "MoistMix", "UnstableInkDream", "bocchi", "OpenNiji", "", "", "", ""]
if dataset == "AnythingV4":
  # %cd {Carpeta_Modelos}
  # !wget https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.5-pruned-fp32.ckpt
  # !wget https://raw.githubusercontent.com/Stability-AI/stablediffusion/main/configs/stable-diffusion/v2-inference.yaml

if dataset == "kenshi":
  # %cd {Carpeta_Modelos}
  # !curl -Lo kenshi_01.safetensors https://civitai.com/api/download/models/6792

if dataset == "Naifu":
  # %cd {Carpeta_Modelos}
  # !apt install -y -qq aria2
  # !aria2c --summary-interval=5 -x 3 --allow-overwrite=true -Z \
    https://doc-0g-20-docs.googleusercontent.com/docs/securesc/61n27pl672b2onjrnc614dl7sgtkqs9o/q4oqsts0scnevsvqj1mudf9nf84o7imb/1671753750000/18257119988972949119/09638222410879992641/1-4uV3kvQdtMeUxXYwCgT18le6Zcjilxy?e=download&ax=ALjR8syXfgR_AlzRWPno4guuvOp4_KYJBlWHXLAUdu4XP7tifia0k_OA6d9KTiZN87pMrFm2DpbFGVAT91unrLT_F_aK5A6j-kZEVJtpoGIxPHhmmjXcu3zbx96WvL0Iav_iv5lyH8WQPYoeCAs4FI83eSChYeC31PCThDiLbj65OhXnFvr-8JdK_4ywyio_kdc4dbu0zDOS5q003Be7KoVlHL6UqEUbKEszMRSEUrD3NvgI_1ycYEbmv_pLaBKxoswKnRxPIueHUI0OXuiJif15DfY8a-6OrI1-6ZCO5ZYIGhu362vXsQ8fZ_p0bXaTIF-CT4o2SpIrc8vPnW-aJf4PHSpMDtk1MFLRVk6piWNytIlkIyNl15nH_KOkPUQevixRaPtV8jRdQ36sMsxz_hJh6RMUoT-9QHJjGeKHZoht1TrfX-_f0U-8PZgvfsbLkEz_vtz3BnbM6VDc1Hd7CbMkoQXjqTyKpjkMNdnSBsPaF52pk3FMUAcP-1lNpuO86AOU7Uhjr6vLO1Gg2xysAoQQJQ-P7vP2yf4pN8wjq0f3eibfWThryd0sMYe60NedaaAXHoacSLoqPKTdxHwrLZlv04G7s3gdQMVI9ZkItkLTV3bavIJLBFSe_jaeKngmXiG0Ldw5js7EZc2TLHdspjlPyptTOg5gb0QbOaAwqjwFksEQeUlYpK2RA2oBAnuszU5CiHyyyBEF5OlM821lPNdTWsIGK1bBGafHKntAL62vGapwzgZJgxU-UVKtW1Xv0z2ER9Kesqm_XnLwi7RnsgKOVF6fa0p1nFb1FSdy-wwCfkdvqWXzkMx24A7KwhUr333Dji4tlhs9jCmtKKUxYgK0oh9fla59eTaueq0V_cZGvBX5_PtcTZ2lAMx-KGWm7sLxjSWbjx48ipNVuuMx5f8wVlSmzJ_8rn8K1Pff4bC0P3eCsF7b11TGEgH08Sir4K9PSOkggYFC&uuid=68d15beb-97df-4478-979f-fbeae7402fc9&authuser=0&nonce=bhjqkb5siq5k8&user=09638222410879992641&hash=5u3o2jnmpc121e0a43o86s1keug1i65d \
  
if dataset == "Waifuv1-4":
  # %cd {Carpeta_Modelos}
  # !wget https://huggingface.co/hakurei/waifu-diffusion-v1-4/resolve/main/models/wd-1-3-5_80000-fp32.ckpt

if dataset == "anime":
  # %cd {Carpeta_Modelos}
  # !curl -Lo anime.safetensors https://civitai.com/api/download/models/10861

if dataset == "hitokomoru-v2":
  # %cd {Carpeta_Modelos}
  # !wget https://huggingface.co/Linaqruf/hitokomoru-diffusion-v2/resolve/main/hitokomoru-v2.ckpt
  # !wget https://huggingface.co/Linaqruf/hitokomoru-diffusion-v2/raw/main/model_index.json
  # !wget https://huggingface.co/Linaqruf/hitokomoru-diffusion-v2/raw/main/hitokomoru-v2.yaml

if dataset == "Izumi":
  # %cd {Carpeta_Modelos}
  # !curl -Lo Izumi.safetensors https://civitai.com/api/download/models/2254

if dataset == "Healys Anime Blend":
  # %cd {Carpeta_Modelos}
  # !curl -Lo Healys_Anime_Blend.ckpt https://civitai.com/api/download/models/1498

if dataset == "animefull-latest":
  # %cd {Carpeta_Modelos}
  # !wget https://huggingface.co/tuan123/animefull/resolve/main/animefull-final-pruned.ckpt

if dataset == "Protogen v2.2 Anime":
  # %cd {Carpeta_Modelos}
  # !curl -Lo progenv22.safetensors https://civitai.com/api/download/models/4007
  
if dataset == "grapefruit":
  # %cd {Carpeta_Modelos}
  # !curl -Lo grapefruit.safetensors https://civitai.com/api/download/models/5013

if dataset == "MoistMix":
  # %cd {Carpeta_Modelos}
  # !curl -Lo MoistMix.safetensors https://civitai.com/api/download/models/3829

if dataset == "UnstableInkDream":
  # %cd {Carpeta_Modelos}
  # !curl -Lo UnstableInkDream.safetensors https://civitai.com/api/download/models/5120

if dataset == "OpenNiji":
  # %cd {Carpeta_Modelos}
  # !curl -Lo OpenNiji.safetensors https://civitai.com/api/download/models/5959

if dataset == "bocchi":
  # %cd {Carpeta_Modelos}
  # !curl -Lo bocchi.safetensors https://civitai.com/api/download/models/4654

Drive = True #@param {type:"boolean"}
#@markdown - Conecta con Google Drive
if Drive:
   from google.colab import drive
   drive.mount('/content/drive')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
import time
import sys
import fileinput
import subprocess
from google.colab import runtime
from IPython.display import display_markdown
from IPython.display import clear_output
from subprocess import getoutput
import glob
from google.colab import output
import gc
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
# !gc.collect()


Xformers = True #@param {type:"boolean"}
if Xformers:
  # !pip install -q https://github.com/camenduru/stable-diffusion-webui-colab/releases/download/0.0.15/xformers-0.0.15.dev0+189828c.d20221207-cp38-cp38-linux_x86_64.whl
#@markdown - Instalación de WebUI de Automatic1111, desactivala si ya la tienes descargada


Session__Name="/content/" #@param{type: 'string'}
#@markdown - Pon la ruta de la carpeta de los modelos

Use_Custom_Path = True #@param {type:"boolean"}



#@title Iniciar

CD = "/content/" #@param {type:"string"}
#@markdown - Pon una ruta en CD para que se instalen todas las dependencias ahi mismo, es importante que termine con un "/" al final



extensions = True #@param {type:"boolean"}
if extensions: #@markdown - Descargara extensiones, no es necesario tenerlo activo para que stable diffusion funcione.
  # %cd {CD}/stable-diffusion-webui/extensions
  # !git clone https://github.com/animerl/novelai-2-local-prompt
  # !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete
  # !rm -rf sd_civitai_extension
  # !git clone https://github.com/P2Enjoy/sd-civitai-browser


modelvae="AnythingVAE" #@param ["None", "AnythingVAE", "Naifu", "MoistMix VAE", "NaiVAE"]
if modelvae == "AnythingVAE":
  # %cd {CD}stable-diffusion-webui/models/VAE
  # !curl -Lo Anythingmodel.vae.pt https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt

if modelvae == "NaiVAE":
  # %cd {CD}stable-diffusion-webui/models/VAE
  # !curl -Lo nai.vae.pt https://huggingface.co/WarriorMama777/OrangeMixs/resolve/main/VAEs/orangemix.vae.pt

if modelvae == "MoistMix VAE":
  # %cd {CD}stable-diffusion-webui/models/VAE
  # !curl -Lo MoistMix.vae.pt https://civitai.com/api/download/models/3829?type=VAE

loraa = "" #@param ["animescreencap", "Hinata Hyuuga LoRA", "Aqua (Konosuba) LoRA", "Eris (Mushoku Tensei)", "BREASTS_ON_GLASS", ""]
if loraa == "animescreencap":
  # %cd {CD}stable-diffusion-webui/models/Lora
  # !curl -Lo animescreencap.safetensors https://civitai.com/api/download/models/5742

if loraa == "Hinata Hyuuga LoRA":
  # %cd {CD}stable-diffusion-webui/models/Lora
  # !curl -Lo hinata.safetensors https://civitai.com/api/download/models/5480

if loraa == "Aqua (Konosuba) LoRA":
  # %cd {CD}stable-diffusion-webui/models/Lora
  # !curl -Lo aqua.safetensors https://civitai.com/models/5902/aqua-konosuba-lora

if loraa == "Eris (Mushoku Tensei)":
  # %cd {CD}stable-diffusion-webui/models/Lora
  # !curl -Lo eris.safetensors https://civitai.com/models/5345/eris-mushoku-tensei

if loraa == "BREASTS_ON_GLASS":
  # %cd {CD}stable-diffusion-webui/models/Lora
  # !curl -Lo BREASTS_ON_GLASS.safetensors https://civitai.com/api/download/models/8614



textual_inversion = "" #@param ["corneo_covering_breasts_two_hands", "Marin_Kitagawa", "xd", "", ""]
if textual_inversion == "corneo_covering_breasts_two_hands":
  # %cd {CD}stable-diffusion-webui/embeddings
  # !curl -Lo corneo_covering_breasts_two_hands.pt https://civitai.com/api/download/models/6033

if textual_inversion == "Marin_Kitagawa":
  # %cd {CD}stable-diffusion-webui/embeddings
  # !curl -Lo corneo_marin_kitagawa.pt https://civitai.com/api/download/models/6093

if textual_inversion == "xd":
  # %cd {CD}stable-diffusion-webui/models/Lora
  # !curl -Lo mt_eriç.safetensors https://civitai.com/models/5345/eris-mushoku-tensei


if textual_inversion == "":
  # %cd {CD}stable-diffusion-webui/embeddings
  # !curl -Lo .pt 

if textual_inversion == "":
  # %cd {CD}stable-diffusion-webui/embeddings
  # !curl -Lo .pt 

if textual_inversion == "":
  # %cd {CD}stable-diffusion-webui/embeddings
  # !curl -Lo .pt 

if textual_inversion == "":
  # %cd {CD}stable-diffusion-webui/embeddings
  # !curl -Lo .pt 


try:
  INSTANCE_NAME
  INSTANCET=INSTANCE_NAME  
except:
  pass

if Session__Name!="":
  INSTANCET=Session__Name
  INSTANCET=INSTANCET.replace(" ","_")

if Use_Custom_Path:
  try:
    INSTANCET
    del INSTANCET
  except:
    pass

try:
  INSTANCET
  if Session__Name!="":
    path_to_trained_model="{Session__Name}*.ckpt"
    ckpt_files = glob.glob(path_to_trained_model + '/**/*.ckpt', recursive=True)
  else:
    path_to_trained_model='/content/models'
except:
  print('No se ha encontrado ningun modelo asi que introduzca su ruta')
  path_to_trained_model=input()
     
if Session__Name:
  configf=""
  # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cpu"):@' /usr/local/lib/python3.8/dist-packages/open_clip/factory.py
  NM="False"

if os.path.exists('/usr/local/lib/python3.8/dist-packages/xformers'):
  xformers="--xformers" 
else:
  xformers=""


if os.path.isfile(path_to_trained_model):
  # %cd {CD}stable-diffusion-webui
  # !python launch.py --share --api --lowram --enable-insecure-extension-access --listen --disable-safe-unpickle --xformers --reinstall-xformers --no-half --ckpt "$path_to_trained_model"

else:
  # %cd {CD}stable-diffusion-webui
  # !python launch.py --share --api --lowram --enable-insecure-extension-access --listen --disable-safe-unpickle --xformers --reinstall-xformers --no-half --ckpt-dir "$path_to_trained_model"

# %%
import os
import time
import sys
import fileinput
import subprocess
from google.colab import runtime
from IPython.display import display_markdown
from IPython.display import clear_output
from subprocess import getoutput
import glob
import torch
from torch import autocast
from google.colab import output
import gc
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
# !gc.collect()
Session__Name="/content/models/Anything-v4.5-pruned-fp32.ckpt" 

Use_Custom_Path = True 



#@title Iniciar si es que ya iniciaste con la de arriba

CD = "/content/" 


try:
  INSTANCE_NAME
  INSTANCET=INSTANCE_NAME  
except:
  pass

if Session__Name!="":
  INSTANCET=Session__Name
  INSTANCET=INSTANCET.replace(" ","_")

if Use_Custom_Path:
  try:
    INSTANCET
    del INSTANCET
  except:
    pass

try:
  INSTANCET
  if Session__Name!="":
    path_to_trained_model="{Session__Name}*.ckpt"
    ckpt_files = glob.glob(path_to_trained_model + '/**/*.ckpt', recursive=True)
  else:
    path_to_trained_model='/content/models'
except:
  print('No se ha encontrado ningun modelo asi que introduzca su ruta')
  path_to_trained_model=input()
     
if Session__Name:
  configf=""
  # !sed -i 's@def load_state_dict(checkpoint_path: str, map_location.*@def load_state_dict(checkpoint_path: str, map_location="cpu"):@' /usr/local/lib/python3.8/dist-packages/open_clip/factory.py
  NM="False"

if os.path.exists('/usr/local/lib/python3.8/dist-packages/xformers'):
  xformers="--xformers" 
else:
  xformers=""

if os.path.isfile(path_to_trained_model):
  # %cd {CD}stable-diffusion-webui
  # !python launch.py --share --api --lowram --enable-insecure-extension-access --listen --disable-safe-unpickle --xformers --reinstall-xformers --no-half --ckpt "$path_to_trained_model"

else:
  # %cd {CD}stable-diffusion-webui
  # !python launch.py --share --api --lowram --enable-insecure-extension-access --listen --disable-safe-unpickle --xformers --reinstall-xformers --no-half --ckpt-dir "$path_to_trained_model"

# %%
#@title Consola de Python 
#@markdown curl -Lo Iino_Miko.safetensors https://civitai.com/api/download/models/10476
#@markdown curl -Lo megumin.safetensors https://civitai.com/api/download/models/10571 
#@markdown curl -Lo hinata.safetensors https://civitai.com/api/download/models/5480
#@markdown curl -Lo corneo_marin_kitagawa.pt https://civitai.com/api/download/models/6093
#@markdown curl -Lo mt_eric.safetensors https://civitai.com/models/5345/eris-mushoku-tensei
#@markdown curl -Lo amberGenshinImpact_flexibleV1.safetensors https://civitai.com/api/download/models/5105
#@markdown curl -Lo gwenFromLeagueOf_gwenLolV1.safetensors https://civitai.com/models/5025/gwen-from-league-of-legends
#@markdown curl -Lo reze.safetensors https://civitai.com/api/download/models/7660
#@markdown curl -Lo akali_v2-000038.safetensors https://civitai.com/api/download/models/6447
#@markdown curl -Lo nijikaIjichiOfBocchiThe_v10.safetensors https://civitai.com/api/download/models/8889
#@markdown curl -Lo animeScreencapStyle_v230epochs.safetensors https://civitai.com/api/download/models/5742
#@markdown curl -Lo poiSpring-000008.safetensors https://civitai.com/api/download/models/8762
#@markdown curl -Lo breasts_on_glass.safetensors https://civitai.com/api/download/models/8614
#@markdown curl -Lo yoimiya_v10.safetensors https://civitai.com/api/download/models/6969
#@markdown curl -Lo hutao_nai.safetensors https://civitai.com/api/download/models/8813
#@markdown curl -Lo SonozakiShion.safetensors https://civitai.com/api/download/models/9578
#@markdown curl -Lo Cosplay-000008.safetensors https://civitai.com/api/download/models/9509
#@markdown curl -Lo Yotsuba.safetensors https://civitai.com/api/download/models/9589



import gc
# !pip install colab-xterm
# %load_ext colabxterm
# %xterm
# !gc.collect()

# %%
# !pip install pysftp

# %%
# !pip install pysftp
import pysftp
cnopts = pysftp.CnOpts()
cnopts.hostkeys = None
with pysftp.Connection('192.168.1.5', username='Santiago Toledo', password='elpacmansantitgu2.', cnopts=cnopts) as sftp:

# %%
import paramiko

# Crea una conexión SSH
ssh = paramiko.SSHClient()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh.connect('186.48.9.210', username='Santiago Toledo', password='elpacmansantitgu2.')

# Descarga el modelo desde tu PC
sftp = ssh.open_sftp()
sftp.get('X:\ ')
sftp.close()

# %%
# !pip install paramiko
